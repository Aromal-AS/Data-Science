# %%
import matplotlib.pyplot as plt
student_data = [5,15,25,35,45,55]
plt.hist(student_data,bins=[0,10,20,30,40,50,60],weights=[20,10,45,33,6,8],ec='red')#histtype="bar" rwidth=0./"step"/"stepfilled"
plt.title('students count')
plt.xlabel('No.of students')
plt.ylabel('student count')
# plt.xticks([10,20,30])
plt.show()
